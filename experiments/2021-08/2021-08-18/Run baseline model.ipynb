# %% [markdown]
# Aim is to a simple baseline model that just uses the last value of pv yield to predict the following values

# %%
# setup
from predict_pv_yield.models.baseline.last_value import Model
import pytorch_lightning as pl
from predict_pv_yield.data.dataloader import get_dataloaders

import logging

logging.basicConfig()
_LOG = logging.getLogger("predict_pv_yield")
_LOG.setLevel(logging.DEBUG)

# %%
# get data loaders
train_dataloader, validation_dataloader = get_dataloaders()
model = Model()
trainer = pl.Trainer(gpus=0, max_epochs=1)

# run through results
results = trainer.test(model, validation_dataloader)
print(results)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Testing: 0it [00:00, ?it/s]
# /Users/peterdudfield/miniconda3/envs/predict_pv_yield/lib/python3.9/site-packages/google/auth/_default.py:70: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ...
